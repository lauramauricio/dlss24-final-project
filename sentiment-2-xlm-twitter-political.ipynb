# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
from scipy.special import softmax

# %%
df = pd.read_csv("./data/classified_manifestos_pre99.csv")
df.head()
# Out:
#    party    date                                               text  \
# 0  43320  196310  ARBEITSPROGRAMM 1963  Vor 75 Jahren erfolgte d...
# 1  43320  196310  In Würdigung dieses historischen und für die w...
# 2  43320  196310  Recht auf Bildung — Chancen für die Jugend  De...
# 3  43320  196310  Jedermann soll Anteil an den kulturellen Werte...
# 4  43320  196310  Was dem ganzen Volke und vornehmlich der Jugen...
#
#                        topic
# 0  305 - Political Authority
# 1            202 - Democracy
# 2  506 - Education Expansion
# 3    502 - Culture: Positive
# 4  506 - Education Expansion

# %%
# Split the topic into the cmp_code
df["cmp_code"] = df["topic"].str.split(" - ", n=1, expand=True).loc[:,0]
df
# Out:
#        party    date                                               text  \
# 0      43320  196310  ARBEITSPROGRAMM 1963  Vor 75 Jahren erfolgte d...
# 1      43320  196310  In Würdigung dieses historischen und für die w...
# 2      43320  196310  Recht auf Bildung — Chancen für die Jugend  De...
# 3      43320  196310  Jedermann soll Anteil an den kulturellen Werte...
# 4      43320  196310  Was dem ganzen Volke und vornehmlich der Jugen...
# ...      ...     ...                                                ...
# 14722  43810  199510  • dass der körperliche Drogenentzug weiterhin ...
# 14723  43810  199510  • dass sowohl der Entzug mit medikamentöser Be...
# 14724  43810  199510  Der Entzug muss auch gegen den Willen der Betr...
# 14725  43810  199510  Es sind die geeigneten Massnahmen dafür bereit...
# 14726  43810  199510  • Hilfeleistung für ehemalige Drogenabhängige ...
#
#                                 topic cmp_code
# 0           305 - Political Authority      305
# 1                     202 - Democracy      202
# 2           506 - Education Expansion      506
# 3             502 - Culture: Positive      502
# 4           506 - Education Expansion      506
# ...                               ...      ...
# 14722   504 - Welfare State Expansion      504
# 14723   504 - Welfare State Expansion      504
# 14724  201 - Freedom and Human Rights      201
# 14725   605 - Law and Order: Positive      605
# 14726   504 - Welfare State Expansion      504
#
# [14727 rows x 5 columns]

# %%
# Add dictionary for mapping party IDs to party names
party_name_mapping = {
    43110: "GPS",
    43120: "GLP",
    43320: "SPS",
    43420: "FDP",
    43520: "CVP",
    43810: "SVP",
    43811: "BDP"
}

# Map the party IDs to the new 'party_name' column
df['party_name'] = df['party'].map(party_name_mapping)

df
# Out:
#        party    date                                               text  \
# 0      43320  196310  ARBEITSPROGRAMM 1963  Vor 75 Jahren erfolgte d...
# 1      43320  196310  In Würdigung dieses historischen und für die w...
# 2      43320  196310  Recht auf Bildung — Chancen für die Jugend  De...
# 3      43320  196310  Jedermann soll Anteil an den kulturellen Werte...
# 4      43320  196310  Was dem ganzen Volke und vornehmlich der Jugen...
# ...      ...     ...                                                ...
# 14722  43810  199510  • dass der körperliche Drogenentzug weiterhin ...
# 14723  43810  199510  • dass sowohl der Entzug mit medikamentöser Be...
# 14724  43810  199510  Der Entzug muss auch gegen den Willen der Betr...
# 14725  43810  199510  Es sind die geeigneten Massnahmen dafür bereit...
# 14726  43810  199510  • Hilfeleistung für ehemalige Drogenabhängige ...
#
#                                 topic cmp_code party_name
# 0           305 - Political Authority      305        SPS
# 1                     202 - Democracy      202        SPS
# 2           506 - Education Expansion      506        SPS
# 3             502 - Culture: Positive      502        SPS
# 4           506 - Education Expansion      506        SPS
# ...                               ...      ...        ...
# 14722   504 - Welfare State Expansion      504        SVP
# 14723   504 - Welfare State Expansion      504        SVP
# 14724  201 - Freedom and Human Rights      201        SVP
# 14725   605 - Law and Order: Positive      605        SVP
# 14726   504 - Welfare State Expansion      504        SVP
#
# [14727 rows x 6 columns]

# %%
# Function to map cmp_code to main_topic
def map_to_main_topic(cmp_code):
    if str(cmp_code).startswith('1'):
        return "external relations"
    elif str(cmp_code).startswith('2'):
        return "freedom and democracy"
    elif str(cmp_code).startswith('3'):
        return "political system"
    elif str(cmp_code).startswith('4'):
        return "economy"
    elif str(cmp_code).startswith('5'):
        return "welfare and quality of life"
    elif str(cmp_code).startswith('6'):
        return "fabric of society"
    elif str(cmp_code).startswith('7'):
        return "social groups"
    else:
        return "other"  # Optional: For any other cases

# Add a new column 'main_topic' based on the 'cmp_code'
df['main_topic'] = df['cmp_code'].apply(map_to_main_topic)

df.head()
# Out:
#    party    date                                               text  \
# 0  43320  196310  ARBEITSPROGRAMM 1963  Vor 75 Jahren erfolgte d...
# 1  43320  196310  In Würdigung dieses historischen und für die w...
# 2  43320  196310  Recht auf Bildung — Chancen für die Jugend  De...
# 3  43320  196310  Jedermann soll Anteil an den kulturellen Werte...
# 4  43320  196310  Was dem ganzen Volke und vornehmlich der Jugen...
#
#                        topic cmp_code party_name                   main_topic
# 0  305 - Political Authority      305        SPS             political system
# 1            202 - Democracy      202        SPS        freedom and democracy
# 2  506 - Education Expansion      506        SPS  welfare and quality of life
# 3    502 - Culture: Positive      502        SPS  welfare and quality of life
# 4  506 - Education Expansion      506        SPS  welfare and quality of life

# %%
# Save dataset for pre-1999 manifestos
df.to_pickle("./data/df_pre1999.pkl")

# %%
# Load dataset for 1999 and post manifestos
df_post1999 = pd.read_pickle("./data/df_all.pkl")
df_post1999
# Out:
#        party       date                                               text  \
# 0      43110 1999-10-01                      For a sustainable Switzerland
# 1      43110 1999-10-01                             Election platform 1999
# 2      43110 1999-10-01  The Greens are pleased to present an election ...
# 3      43110 1999-10-01    - to briefly present a sustainable Switzerland.
# 4      43110 1999-10-01  In responsibility towards future generations, ...
# ...      ...        ...                                                ...
# 18169  43811 2019-10-01  The same is true for other projects that lead ...
# 18170  43811 2019-10-01  Various reforms in the financial center, for e...
# 18171  43811 2019-10-01               They must be seen as an opportunity.
# 18172  43811 2019-10-01  There is no way around the recognition and imp...
# 18173  43811 2019-10-01  It makes sense, however, to avoid unnecessary ...
#
#       cmp_code  eu_code sentiment     score  year party_name  \
# 0          NaN      NaN  POSITIVE  0.998674  1999        GPS
# 1          NaN      NaN  POSITIVE  0.987673  1999        GPS
# 2          501      NaN  POSITIVE  0.998852  1999        GPS
# 3          601      NaN  POSITIVE  0.998062  1999        GPS
# 4          201      NaN  POSITIVE  0.998758  1999        GPS
# ...        ...      ...       ...       ...   ...        ...
# 18169      414      NaN  POSITIVE  0.998668  2019        BDP
# 18170      414      NaN  POSITIVE  0.998879  2019        BDP
# 18171      414      NaN  POSITIVE  0.994448  2019        BDP
# 18172      107      NaN  POSITIVE  0.998304  2019        BDP
# 18173      107      NaN  POSITIVE  0.997164  2019        BDP
#
#                         main_topic
# 0                            other
# 1                            other
# 2      welfare and quality of life
# 3                fabric of society
# 4            freedom and democracy
# ...                            ...
# 18169                      economy
# 18170                      economy
# 18171                      economy
# 18172           external relations
# 18173           external relations
#
# [18174 rows x 10 columns]

# %%
# Unify date formats and drop columns
df_convert = pd.read_pickle("./data/df_pre1999.pkl")
df_convert["date"]= pd.to_datetime(df_convert["date"], format="%Y%m")
drop_col = ["topic"]
df_pre1999 = df_convert.drop(drop_col, axis=1)
df_pre1999
# Out:
#        party       date                                               text  \
# 0      43320 1963-10-01  ARBEITSPROGRAMM 1963  Vor 75 Jahren erfolgte d...
# 1      43320 1963-10-01  In Würdigung dieses historischen und für die w...
# 2      43320 1963-10-01  Recht auf Bildung — Chancen für die Jugend  De...
# 3      43320 1963-10-01  Jedermann soll Anteil an den kulturellen Werte...
# 4      43320 1963-10-01  Was dem ganzen Volke und vornehmlich der Jugen...
# ...      ...        ...                                                ...
# 14722  43810 1995-10-01  • dass der körperliche Drogenentzug weiterhin ...
# 14723  43810 1995-10-01  • dass sowohl der Entzug mit medikamentöser Be...
# 14724  43810 1995-10-01  Der Entzug muss auch gegen den Willen der Betr...
# 14725  43810 1995-10-01  Es sind die geeigneten Massnahmen dafür bereit...
# 14726  43810 1995-10-01  • Hilfeleistung für ehemalige Drogenabhängige ...
#
#       cmp_code party_name                   main_topic
# 0          305        SPS             political system
# 1          202        SPS        freedom and democracy
# 2          506        SPS  welfare and quality of life
# 3          502        SPS  welfare and quality of life
# 4          506        SPS  welfare and quality of life
# ...        ...        ...                          ...
# 14722      504        SVP  welfare and quality of life
# 14723      504        SVP  welfare and quality of life
# 14724      201        SVP        freedom and democracy
# 14725      605        SVP            fabric of society
# 14726      504        SVP  welfare and quality of life
#
# [14727 rows x 6 columns]

# %%
# Drop unnecessary columns in post 1999 dataset
drop_col = ["eu_code","sentiment", "score","year"]
df_post1999 = df_post1999.drop(drop_col, axis=1)
df_post1999
# Out:
#        party       date                                               text  \
# 0      43110 1999-10-01                      For a sustainable Switzerland
# 1      43110 1999-10-01                             Election platform 1999
# 2      43110 1999-10-01  The Greens are pleased to present an election ...
# 3      43110 1999-10-01    - to briefly present a sustainable Switzerland.
# 4      43110 1999-10-01  In responsibility towards future generations, ...
# ...      ...        ...                                                ...
# 18169  43811 2019-10-01  The same is true for other projects that lead ...
# 18170  43811 2019-10-01  Various reforms in the financial center, for e...
# 18171  43811 2019-10-01               They must be seen as an opportunity.
# 18172  43811 2019-10-01  There is no way around the recognition and imp...
# 18173  43811 2019-10-01  It makes sense, however, to avoid unnecessary ...
#
#       cmp_code party_name                   main_topic
# 0          NaN        GPS                        other
# 1          NaN        GPS                        other
# 2          501        GPS  welfare and quality of life
# 3          601        GPS            fabric of society
# 4          201        GPS        freedom and democracy
# ...        ...        ...                          ...
# 18169      414        BDP                      economy
# 18170      414        BDP                      economy
# 18171      414        BDP                      economy
# 18172      107        BDP           external relations
# 18173      107        BDP           external relations
#
# [18174 rows x 6 columns]

# %%
# Combine the two datasets
dfs = [df_pre1999, df_post1999]
dfs = pd.concat(dfs)
dfs.shape
# Out:
# (32901, 6)

# %%
# Save dataframe for the sentiment analysis
dfs.to_csv("./data/manifesto_texts_topics_1963_2019.csv")

# %%
# Load dataset
df_orig = pd.read_csv("/content/drive/MyDrive/dlss24/dlss24/final/manifesto_texts_topics_1963_2019.csv")
df_orig

# %%
# Load model
MODEL = f"cardiffnlp/xlm-twitter-politics-sentiment"
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = model.to(device)

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device

# %%
# Function for sentiment
def sentiment_analyzer_sentences (text):
  encoded_input = tokenizer(text, return_tensors='pt', truncation=True, padding='max_length', max_length=512)
  # Move to GPU
  encoded_input = encoded_input.to(device)

  output = model(**encoded_input)
  scores = output[0][0].cpu().detach().numpy()
  scores = softmax(scores)
  # assigning sentiment label based on highest score index
  sentiment_index = scores.argmax()
  sentiments = ["negative", "neutral", "positive"]
  sentiment = sentiments[sentiment_index]
  return sentiment

# %%
# Apply sentiment function to text 
df = df_orig.copy()
df.loc[:,"sentiment"] = df["text"].apply(sentiment_analyzer_sentences)

# %%
# Saved dataframe
df.to_csv("./data/manifesto-texts-sentiment-1963-2019.csv")
