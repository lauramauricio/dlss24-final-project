# %%
import pandas as pd

# %%
# Check sentiment of 100 randomly drawn sentences
df = pd.read_pickle("./data/df_topic_sentiment_1999-2019.pkl")
df
# Out:
#        party    date                                               text  \
# 0      43110  199910                      For a sustainable Switzerland
# 1      43110  199910                             Election platform 1999
# 2      43110  199910  The Greens are pleased to present an election ...
# 3      43110  199910    - to briefly present a sustainable Switzerland.
# 4      43110  199910  In responsibility towards future generations, ...
# ...      ...     ...                                                ...
# 18169  43811  201910  The same is true for other projects that lead ...
# 18170  43811  201910  Various reforms in the financial center, for e...
# 18171  43811  201910               They must be seen as an opportunity.
# 18172  43811  201910  There is no way around the recognition and imp...
# 18173  43811  201910  It makes sense, however, to avoid unnecessary ...
#
#       cmp_code  eu_code sentiment     score
# 0          NaN      NaN  POSITIVE  0.998674
# ...

# %%
df_check = df.sample(100)
df_check
# Out:
#        party    date                                               text  \
# 14386  43420  201910  The FDP is fighting against this and is commit...
# 12690  43810  201510  Furthermore, mechanisms are to be put in place...
# 13642  43110  201910  a broad campaign against racist, sexist or hom...
# 2853   43320  200310  More attention should be paid to mathematics a...
# 12553  43810  201510  The federal government is now even striving fo...
# ...      ...     ...                                                ...
# 15136  43520  201910  The CVP calls for reliable and affordable chil...
# 14413  43420  201910  Basic right for citizens to understandable, si...
# 5220   43110  200710  The conservative parties have submitted countl...
# 1838   43810  199910  The organized groups no longer stop at any bor...
# 12485  43810  201510  Copyright companies such as SUISA, Pro Litteri...
#
#       cmp_code  eu_code sentiment     score
# 14386    201.1      NaN  POSITIVE  0.998837
# ...
